# %%
import numpy as np

# %%
t = np.arange(10) / 44000
wave = np.sin(2 * np.pi * 440 * t)

# %%
a
# Out:
# array([0.        , 0.06279052, 0.12533323, 0.18738131, 0.24868989,
#        0.30901699, 0.36812455, 0.42577929, 0.48175367, 0.53582679])

# %%
from beeper.beeper import Beeper

# %%
beeper = Beeper()
